# %%
import pandas as pd

# %%
DATA_PATH = "archive/"
followers = pd.read_csv(DATA_PATH + "followers.tsv", sep='\t')

# %%
followers.head()
# Out:
#                    followed_user_id                  follower_user_id
# 0  b99ebf68a8d93f024e56c65e2f949b57  1ebda3c5e05265626ab18401fb33a90a
# 1  c1066039fa61eede113878259c1222d1  1ebda3c5e05265626ab18401fb33a90a
# 2  d8a96caeef5c7d8dbdc9cec28aa9c044  1ebda3c5e05265626ab18401fb33a90a
# 3  2969c319775d884b860a897ba9d6156f  1ebda3c5e05265626ab18401fb33a90a
# 4  ff58e67948917e0ff71ba4b33e158365  1ebda3c5e05265626ab18401fb33a90a

# %%
jams = pd.read_csv(DATA_PATH + "jams.tsv", sep='\t', error_bad_lines=False)
jams.head()
# Out:
# b'Skipping line 58038: expected 7 fields, saw 8\nSkipping line 58738: expected 7 fields, saw 8\n'
# b'Skipping line 847113: expected 7 fields, saw 8\n'
# b'Skipping line 1091137: expected 7 fields, saw 8\nSkipping line 1175359: expected 7 fields, saw 8\n'
# b'Skipping line 1225919: expected 7 fields, saw 8\nSkipping line 1255341: expected 7 fields, saw 8\nSkipping line 1279655: expected 7 fields, saw 8\n'
# b'Skipping line 1330659: expected 7 fields, saw 8\n'
# b'Skipping line 1448017: expected 7 fields, saw 8\nSkipping line 1543877: expected 7 fields, saw 8\n'
# b'Skipping line 1579553: expected 7 fields, saw 8\nSkipping line 1612432: expected 7 fields, saw 8\n'
# b'Skipping line 1784572: expected 7 fields, saw 8\n'
#                              jam_id                           user_id  \
# 0  c2e76bb92c7fa733fdfc9be40bb0e4ea  b99ebf68a8d93f024e56c65e2f949b57
# 1  5d2bc46196d7903a5580f0dbedc09610  c1066039fa61eede113878259c1222d1
# 2  4849f8c893a792032dbc15eb77cfd0cd  d8a96caeef5c7d8dbdc9cec28aa9c044
# 3  8940ff2e8e38c8f1a4676e09d152c0cd  b1c81a51f5286d70e5820ecb85aeba96
# 4  4020b45a4c6d5515a3b62c489e169828  4fdc0257bc476bffd3e73564ecaa75e0
#
#                artist                   title creation_date link  \
# 0        Orange Juice               Rip It Up    2011-08-26  NaN
# 1         Erkin Koray                Hele Yar    2011-08-26  NaN
# 2              Stereo  Somewhere In the Night    2011-08-26  NaN
# 3  The Mills Brothers  I Got Her Off My Hands    2011-08-26  NaN
# 4             Various           Zum Volksfest    2011-08-26  NaN
#
#                             spotify_uri
# 0  spotify:track:6AGhDIyDbRonzGTdbIsNXa
# 1                                   NaN
# 2  spotify:track:2ZM9sVP0blBj1lNIEg4dgn
# 3  spotify:track:096elxAmYuyAFJKPLrS5oY
# 4                                   NaN

# %%
jams.sample(10)
# Out:
#                                    jam_id                           user_id  \
# 804574   0324df396db6fc61a167755348244b1e  1ec3e7d1427f896ad8da1ccd7ebb5aed
# 1526074  07ddd96f1b9139b8ecfcfa3729cdf7ab  4468d246e2d0bf75992cebe60c891f3a
# 1720205  2dcd4b989d21974139059db606301c0a  a56537f0a4a0dd5e4619a4d6957fbf91
# 1769158  f0359dac309adedd0af0879846b8f806  366b237a4f824495cbd4dfdd75bfda19
# 1665746  c2705931c5f585dd54c3040c2cf0cdf7  a07fdcc116fbb4d9193ccb6c847571cb
# 257367   3fc2bc5389751876f8d6826ddce27843  14397773c0a60c0bb5c4014535a09ca0
# 930376   5f2e85abf85f5cf201f045c2ece47328  5e3fdc8320fda05e4d2f45ce7cc5bad1
# 1879283  2894b8b2c77b48e649bf80b2a19b75fc  3340447331cc4c85750c2af641520fbe
# 1180616  cae932a94074b84ec0a2fc1d44b11541  67cdb9e2a68b9c7328388b3f16395f58
# 299509   c6e1ae2a3a0479365e7f9341d9535416  1be2fff18647bdf87bc4298381c44380
#
#                           artist                      title creation_date  \
# 804574                LindstrÃ¸m               RÃ -Ã kÃµ-st    2012-12-29
# 1526074             The Contours  First I Look at the Purse    2014-02-15
# 1720205                 Maroon 5          It was always you    2014-07-31
# 1769158                     Ludo       Girls On Trampolines    2014-09-15
# 1665746  Van der Graaf Generator                   Lemmings    2014-06-09
# 257367               Sonic Youth                 Kool Thing    2012-04-28
# 930376                Supergrass          Kick In The Teeth    2013-02-27
# 1879283                   Twerps                  Hypocrite    2015-01-08
# 1180616             Van Morrison                  Fair Play    2013-06-28
# 299509             Nicky Bulldog             Dog Power Song    2012-05-13
#
#                                                link  \
# 804574   http://www.youtube.com/watch?v=gN-JYkTxj5U
# 1526074                 http://hypem.com/item/21qk7
# 1720205  http://www.youtube.com/watch?v=Hsfljo6qhdg
# 1769158  http://www.youtube.com/watch?v=3-e3KXBxf4k
# 1665746  http://www.youtube.com/watch?v=Ovg0IA_QFC0
# 257367   http://www.youtube.com/watch?v=VyfazvK1mUw
# 930376   http://www.youtube.com/watch?v=MNOmCeWJWsw
# 1879283                 http://hypem.com/item/26dmk
# 1180616  http://www.youtube.com/watch?v=Z1vYs5LBC3c
# 299509   http://www.youtube.com/watch?v=SotFoI0j5pc
#
#                                   spotify_uri
# 804574   spotify:track:00AOJueOnewchf2DiaOq8q
# 1526074  spotify:track:56MMFoImGSMkVwI0FH5JeP
# 1720205  spotify:track:0xjjQwCC9lOOD258TUzp5j
# 1769158  spotify:track:318y6Oejz2Zc79JTc1z6MB
# 1665746  spotify:track:3r8aTVJlryuF3ZcVSpWpA0
# 257367   spotify:track:02NjS2MNrjsdxiQNfrl7zz
# 930376   spotify:track:38cA51De9Cen9bQBTs8xtQ
# 1879283  spotify:track:5PQQuIXRIfyWUohE1fpcR1
# 1180616                                   NaN
# 299509                                    NaN
